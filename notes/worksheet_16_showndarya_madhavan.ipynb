# %% [markdown]
# # Worksheet 16
#
# Name:  SHOWNDARYA MADHAVAN
# UID: U10380918
#
# ### Topics
#
# - Logistic Regression
#
# ## Logistic Regression

# %%
import numpy as np
import matplotlib.pyplot as plt
import sklearn.datasets as datasets
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import PolynomialFeatures

centers = [[0, 0]]
t, _ = datasets.make_blobs(n_samples=750, centers=centers, cluster_std=1, random_state=0)

# LINE
def generate_line_data():
    # create some space between the classes
    X = np.array(list(filter(lambda x : x[0] - x[1] < -.5 or x[0] - x[1] > .5, t)))
    Y = np.array([1 if x[0] - x[1] >= 0 else 0 for x in X])
    return X, Y

# CIRCLE
def generate_circle_data(t):
    # create some space between the classes
    X = np.array(list(filter(lambda x : (x[0] - centers[0][0])**2 + (x[1] - centers[0][1])**2 < 1 or (x[0] - centers[0][0])**2 + (x[1] - centers[0][1])**2 > 1.5, t)))
    Y = np.array([1 if (x[0] - centers[0][0])**2 + (x[1] - centers[0][1])**2 >= 1 else 0 for x in X])
    return X, Y

# XOR
def generate_xor_data():
    X = np.array([
        [0,0],
        [0,1],
        [1,0],
        [1,1]])
    Y = np.array([x[0]^x[1] for x in X])
    return X, Y

# %% [markdown]
# a) Using the above code, generate and plot data that is linearly separable.

# %%
X, Y = generate_line_data()
plt.scatter(X[:, 0], X[:, 1], c=Y.tolist(), s=50, alpha=0.9)
plt.show()

# %% [markdown]
# b) Fit a logistic regression model to the data a print out the coefficients.

# %%
model = LogisticRegression().fit(X, Y)
beta = model.coef_
intercept = model.intercept_
model.coef_
model.intercept_
# Out:
# array([0.05839469])

# %% [markdown]
# c) Using the coefficients, plot the line through the scatter plot you created in a). (Note: you need to do some math to get the line in the right form)

# %%
xplot = np.linspace(-3,3)
decision_boundary = intercept /beta[0][0] - beta[0][1] * xplot / beta[0][0]
plt.scatter(X[:,0], X[:,1], c=Y)
plt.plot(xplot,decision_boundary)
plt.show()

# %% [markdown]
# d) Using the above code, generate and plot the CIRCLE data.

# %%
X, Y = generate_circle_data(t)
plt.scatter(X[:,0], X[:,1], c=Y)
plt.show()

# %% [markdown]
# e) Notice that the equation of an ellipse is of the form $$ax^2 + by^2 = c$$
#
# Fit a logistic regression model to an appropriate transformation of X.

# %%
model = LogisticRegression().fit(X, Y)
beta=model.coef_
intercept = model.intercept_
print(model.coef_)
print(model.intercept_)
# Out:
# [[-0.06183417 -0.01164363]]
# [0.09334628]

# %% [markdown]
# f) Plot the decision boundary using the code below.

# %%
# create a mesh to plot in
h = .02  # step size in the mesh
x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))
meshData = np.c_[xx.ravel(), yy.ravel()]

fig, ax = plt.subplots()
A = model.predict_proba(meshData)[:, 1].reshape(xx.shape)
Z = model.predict(meshData).reshape(xx.shape)
ax.contourf(xx, yy, A, cmap="RdBu", vmin=0, vmax=1)
ax.axis('off')

# Plot also the training points
ax.scatter(X[:, 0], X[:, 1], c=Y, s=50, alpha=0.9)
plt.show()

# %% [markdown]
# g) Plot the XOR data. In this 2D space, the data is not linearly separable, but by introducing a new feature $$x_3 = x_1 * x_2$$
#
# (called an interaction term) we should be able to find a hyperplane that separates the data in 3D. Plot this new dataset in 3D.

# %%
# !pip3 install ipympl
# Out:
# Requirement already satisfied: ipympl in /Users/showndaryamadhavan/opt/anaconda3/lib/python3.9/site-packages (0.9.3)
# Requirement already satisfied: ipython-genutils in /Users/showndaryamadhavan/opt/anaconda3/lib/python3.9/site-packages (from ipympl) (0.2.0)
# Requirement already satisfied: numpy in /Users/showndaryamadhavan/opt/anaconda3/lib/python3.9/site-packages (from ipympl) (1.21.5)
# Requirement already satisfied: pillow in /Users/showndaryamadhavan/opt/anaconda3/lib/python3.9/site-packages (from ipympl) (9.2.0)
# Requirement already satisfied: traitlets<6 in /Users/showndaryamadhavan/opt/anaconda3/lib/python3.9/site-packages (from ipympl) (5.1.1)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in /Users/showndaryamadhavan/opt/anaconda3/lib/python3.9/site-packages (from ipympl) (7.6.5)
# Requirement already satisfied: ipython<9 in /Users/showndaryamadhavan/opt/anaconda3/lib/python3.9/site-packages (from ipympl) (7.31.1)
# Requirement already satisfied: matplotlib<4,>=3.4.0 in /Users/showndaryamadhavan/opt/anaconda3/lib/python3.9/site-packages (from ipympl) (3.5.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/showndaryamadhavan/opt/anaconda3/lib/python3.9/site-packages (from ipython<9->ipympl) (3.0.20)
# Requirement already satisfied: pexpect>4.3 in /Users/showndaryamadhavan/opt/anaconda3/lib/python3.9/site-packages (from ipython<9->ipympl) (4.8.0)
# Requirement already satisfied: pickleshare in /Users/showndaryamadhavan/opt/anaconda3/lib/python3.9/site-packages (from ipython<9->ipympl) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in /Users/showndaryamadhavan/opt/anaconda3/lib/python3.9/site-packages (from ipython<9->ipympl) (63.4.1)
# Requirement already satisfied: matplotlib-inline in /Users/showndaryamadhavan/opt/anaconda3/lib/python3.9/site-packages (from ipython<9->ipympl) (0.1.6)
# Requirement already satisfied: appnope in /Users/showndaryamadhavan/opt/anaconda3/lib/python3.9/site-packages (from ipython<9->ipympl) (0.1.2)
# Requirement already satisfied: backcall in /Users/showndaryamadhavan/opt/anaconda3/lib/python3.9/site-packages (from ipython<9->ipympl) (0.2.0)
# Requirement already satisfied: pygments in /Users/showndaryamadhavan/opt/anaconda3/lib/python3.9/site-packages (from ipython<9->ipympl) (2.11.2)
# Requirement already satisfied: jedi>=0.16 in /Users/showndaryamadhavan/opt/anaconda3/lib/python3.9/site-packages (from ipython<9->ipympl) (0.18.1)
# Requirement already satisfied: decorator in /Users/showndaryamadhavan/opt/anaconda3/lib/python3.9/site-packages (from ipython<9->ipympl) (5.1.1)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /Users/showndaryamadhavan/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets<9,>=7.6.0->ipympl) (3.5.2)
# Requirement already satisfied: nbformat>=4.2.0 in /Users/showndaryamadhavan/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets<9,>=7.6.0->ipympl) (5.5.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/showndaryamadhavan/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets<9,>=7.6.0->ipympl) (6.15.2)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /Users/showndaryamadhavan/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets<9,>=7.6.0->ipympl) (1.0.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/showndaryamadhavan/opt/anaconda3/lib/python3.9/site-packages (from matplotlib<4,>=3.4.0->ipympl) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in /Users/showndaryamadhavan/opt/anaconda3/lib/python3.9/site-packages (from matplotlib<4,>=3.4.0->ipympl) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /Users/showndaryamadhavan/opt/anaconda3/lib/python3.9/site-packages (from matplotlib<4,>=3.4.0->ipympl) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/showndaryamadhavan/opt/anaconda3/lib/python3.9/site-packages (from matplotlib<4,>=3.4.0->ipympl) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/showndaryamadhavan/opt/anaconda3/lib/python3.9/site-packages (from matplotlib<4,>=3.4.0->ipympl) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/showndaryamadhavan/opt/anaconda3/lib/python3.9/site-packages (from matplotlib<4,>=3.4.0->ipympl) (2.8.2)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/showndaryamadhavan/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (7.3.4)
# Requirement already satisfied: debugpy>=1.0 in /Users/showndaryamadhavan/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (1.5.1)
# Requirement already satisfied: psutil in /Users/showndaryamadhavan/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (5.9.0)
# Requirement already satisfied: pyzmq>=17 in /Users/showndaryamadhavan/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (23.2.0)
# Requirement already satisfied: tornado>=6.1 in /Users/showndaryamadhavan/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (6.1)
# Requirement already satisfied: nest-asyncio in /Users/showndaryamadhavan/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (1.5.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/showndaryamadhavan/opt/anaconda3/lib/python3.9/site-packages (from jedi>=0.16->ipython<9->ipympl) (0.8.3)
# Requirement already satisfied: fastjsonschema in /Users/showndaryamadhavan/opt/anaconda3/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets<9,>=7.6.0->ipympl) (2.16.2)
# Requirement already satisfied: jupyter_core in /Users/showndaryamadhavan/opt/anaconda3/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets<9,>=7.6.0->ipympl) (4.11.1)
# Requirement already satisfied: jsonschema>=2.6 in /Users/showndaryamadhavan/opt/anaconda3/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets<9,>=7.6.0->ipympl) (4.16.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/showndaryamadhavan/opt/anaconda3/lib/python3.9/site-packages (from pexpect>4.3->ipython<9->ipympl) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/showndaryamadhavan/opt/anaconda3/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython<9->ipympl) (0.2.5)
# Requirement already satisfied: six>=1.5 in /Users/showndaryamadhavan/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib<4,>=3.4.0->ipympl) (1.16.0)
# Requirement already satisfied: notebook>=4.4.1 in /Users/showndaryamadhavan/opt/anaconda3/lib/python3.9/site-packages (from widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (6.4.12)
# Requirement already satisfied: attrs>=17.4.0 in /Users/showndaryamadhavan/opt/anaconda3/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets<9,>=7.6.0->ipympl) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/showndaryamadhavan/opt/anaconda3/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets<9,>=7.6.0->ipympl) (0.18.0)
# Requirement already satisfied: entrypoints in /Users/showndaryamadhavan/opt/anaconda3/lib/python3.9/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (0.4)
# Requirement already satisfied: argon2-cffi in /Users/showndaryamadhavan/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (21.3.0)
# Requirement already satisfied: nbconvert>=5 in /Users/showndaryamadhavan/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (7.2.8)
# Requirement already satisfied: prometheus-client in /Users/showndaryamadhavan/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (0.14.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in /Users/showndaryamadhavan/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/showndaryamadhavan/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (0.13.1)
# Requirement already satisfied: jinja2 in /Users/showndaryamadhavan/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (3.1.2)
# Requirement already satisfied: importlib-metadata>=3.6 in /Users/showndaryamadhavan/opt/anaconda3/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (4.11.3)
# Requirement already satisfied: mistune<3,>=2.0.3 in /Users/showndaryamadhavan/opt/anaconda3/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (2.0.4)
# Requirement already satisfied: tinycss2 in /Users/showndaryamadhavan/opt/anaconda3/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (1.2.1)
# Requirement already satisfied: defusedxml in /Users/showndaryamadhavan/opt/anaconda3/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (0.7.1)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/showndaryamadhavan/opt/anaconda3/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (0.5.13)
# Requirement already satisfied: bleach in /Users/showndaryamadhavan/opt/anaconda3/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (4.1.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/showndaryamadhavan/opt/anaconda3/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (1.5.0)
# Requirement already satisfied: beautifulsoup4 in /Users/showndaryamadhavan/opt/anaconda3/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (4.11.1)
# Requirement already satisfied: jupyterlab-pygments in /Users/showndaryamadhavan/opt/anaconda3/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (0.1.2)
# Requirement already satisfied: markupsafe>=2.0 in /Users/showndaryamadhavan/opt/anaconda3/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (2.0.1)
# Requirement already satisfied: argon2-cffi-bindings in /Users/showndaryamadhavan/opt/anaconda3/lib/python3.9/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (21.2.0)
# Requirement already satisfied: zipp>=0.5 in /Users/showndaryamadhavan/opt/anaconda3/lib/python3.9/site-packages (from importlib-metadata>=3.6->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (3.8.0)
# Requirement already satisfied: cffi>=1.0.1 in /Users/showndaryamadhavan/opt/anaconda3/lib/python3.9/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/showndaryamadhavan/opt/anaconda3/lib/python3.9/site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (2.3.1)
# Requirement already satisfied: webencodings in /Users/showndaryamadhavan/opt/anaconda3/lib/python3.9/site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (0.5.1)
# Requirement already satisfied: pycparser in /Users/showndaryamadhavan/opt/anaconda3/lib/python3.9/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (2.21)

# %%
#%matplotlib widget # Requires: pip3 install ipympl

from mpl_toolkits.mplot3d import Axes3D

ax = plt.axes(projection='3d')
ax.scatter3D(X[:,0], X[:,1],  X[:,0]*X[:,1], c=Y)
plt.show()

# %% [markdown]
# h) Apply a logistic regression model using the interaction term. Plot the decision boundary.

# %%
poly = PolynomialFeatures(interaction_only=True)
lr = LogisticRegression(verbose=2)
model = make_pipeline(poly, lr).fit(X, Y)
x_min, x_max = X[:,0].min()-0.1, X[:,0].max()+0
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.52625D+02    |proj g|=  1.55000D+01
#
# At iterate    1    f=  4.51347D+02    |proj g|=  4.58110D+00
#
# At iterate    2    f=  4.51228D+02    |proj g|=  1.67206D+00
#
# At iterate    3    f=  4.51209D+02    |proj g|=  2.79819D-02
#
# At iterate    4    f=  4.51209D+02    |proj g|=  2.30595D-02
#
# At iterate    5    f=  4.51209D+02    |proj g|=  2.69098D-02
#
# At iterate    6    f=  4.51209D+02    |proj g|=  5.38087D-02
#
# At iterate    7    f=  4.51209D+02    |proj g|=  1.03522D-01
#
# At iterate    8    f=  4.51209D+02    |proj g|=  1.61036D-01
#
# At iterate    9    f=  4.51209D+02    |proj g|=  1.82326D-01
#
# At iterate   10    f=  4.51208D+02    |proj g|=  1.08429D-01
#
# At iterate   11    f=  4.51208D+02    |proj g|=  3.02804D-02
#
# At iterate   12    f=  4.51208D+02    |proj g|=  5.34182D-03
#
# At iterate   13    f=  4.51208D+02    |proj g|=  6.13800D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     13     15      1     0     0   6.138D-03   4.512D+02
#   F =   451.20815611543003
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
#  This problem is unconstrained.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished

# %% [markdown]
# i) Using the code below that generates 3 concentric circles, fit a logisitc regression model to it and plot the decision boundary.

# %%
t, _ = datasets.make_blobs(n_samples=1500, centers=centers, cluster_std=2,
                                random_state=0)

# CIRCLES
def generate_circles_data(t):
    def label(x):
        if x[0]**2 + x[1]**2 >= 2 and x[0]**2 + x[1]**2 < 8:
            return 1
        if x[0]**2 + x[1]**2 >= 8:
            return 2
        return 0
    # create some space between the classes
    X = np.array(list(filter(lambda x : (x[0]**2 + x[1]**2 < 1.8 or x[0]**2 + x[1]**2 > 2.2) and (x[0]**2 + x[1]**2 < 7.8 or x[0]**2 + x[1]**2 > 8.2), t)))
    Y = np.array([label(x) for x in X])
    return X, Y

X, Y = generate_circles_data(t)

poly = PolynomialFeatures(2)
lr = LogisticRegression(verbose=2)
model = make_pipeline(poly, lr).fit(X, Y)

x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xm, ym = np.meshgrid(np.arange(x_min, x_max, 0.1), np.arange(y_min, y_max, 0.1))
Z = model.predict(np.c_[xm.ravel(), ym.ravel()])
Z = Z.reshape(xm.shape)
plt.contourf(xm, ym, Z, alpha=0.4)
plt.scatter(X[:, 0], X[:, 1], c=Y, edgecolor='black', s=20)
plt.show()
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           21     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.54575D+03    |proj g|=  2.20592D+03
#
# At iterate    1    f=  1.25980D+03    |proj g|=  7.85645D+02
#
# At iterate    2    f=  1.16386D+03    |proj g|=  4.67390D+02
#
# At iterate    3    f=  1.12014D+03    |proj g|=  8.53618D+02
#
# At iterate    4    f=  1.07857D+03    |proj g|=  2.28644D+02
#
# At iterate    5    f=  1.03868D+03    |proj g|=  2.46093D+02
#
# At iterate    6    f=  8.75292D+02    |proj g|=  2.23884D+02
#
# At iterate    7    f=  6.72984D+02    |proj g|=  1.69393D+02
#
# At iterate    8    f=  4.06106D+02    |proj g|=  3.22571D+02
#
# At iterate    9    f=  3.84632D+02    |proj g|=  4.67515D+02
#
# At iterate   10    f=  2.26564D+02    |proj g|=  2.61932D+02
#
# At iterate   11    f=  1.84398D+02    |proj g|=  1.15386D+02
#
# At iterate   12    f=  1.54569D+02    |proj g|=  6.06745D+01
#
# At iterate   13    f=  1.34331D+02    |proj g|=  4.43007D+01
#
# At iterate   14    f=  1.24113D+02    |proj g|=  4.50198D+01
#
# At iterate   15    f=  1.21743D+02    |proj g|=  3.63598D+01
#
# At iterate   16    f=  1.19874D+02    |proj g|=  1.08601D+01
#
# At iterate   17    f=  1.19500D+02    |proj g|=  6.08812D+00
#
# At iterate   18    f=  1.19298D+02    |proj g|=  3.58407D+00
#
# At iterate   19    f=  1.19015D+02    |proj g|=  6.65077D+00
#
# At iterate   20    f=  1.18680D+02    |proj g|=  1.37452D+01
#
# At iterate   21    f=  1.18079D+02    |proj g|=  1.98560D+01
#
# At iterate   22    f=  1.16887D+02    |proj g|=  1.87388D+01
#
# At iterate   23    f=  1.16408D+02    |proj g|=  2.74606D+01
#
# At iterate   24    f=  1.14845D+02    |proj g|=  1.68476D+01
#
# At iterate   25    f=  1.12048D+02    |proj g|=  1.01173D+01
#
# At iterate   26    f=  1.09277D+02    |proj g|=  2.60636D+01
#
# At iterate   27    f=  1.05058D+02    |proj g|=  4.27241D+01
#
# At iterate   28    f=  9.92827D+01    |proj g|=  7.46190D+01
#
# At iterate   29    f=  9.20571D+01    |proj g|=  5.06010D+01
#
# At iterate   30    f=  8.70119D+01    |proj g|=  3.20989D+01
#
# At iterate   31    f=  8.24104D+01    |proj g|=  8.74098D+00
#
# At iterate   32    f=  8.08462D+01    |proj g|=  7.93679D+00
#
# At iterate   33    f=  7.86450D+01    |proj g|=  1.85045D+01
#
# At iterate   34    f=  7.57509D+01    |proj g|=  2.16495D+01
#
# At iterate   35    f=  7.48794D+01    |proj g|=  2.70982D+01
#
# At iterate   36    f=  7.30267D+01    |proj g|=  4.78293D+00
#
# At iterate   37    f=  7.28149D+01    |proj g|=  2.79623D+00
#
# At iterate   38    f=  7.26223D+01    |proj g|=  2.74530D+00
#
# At iterate   39    f=  7.24812D+01    |proj g|=  4.17543D+00
#
# At iterate   40    f=  7.24079D+01    |proj g|=  3.65780D+00
#
# At iterate   41    f=  7.23176D+01    |proj g|=  2.28953D+00
#
# At iterate   42    f=  7.22311D+01    |proj g|=  1.40639D+00
#
# At iterate   43    f=  7.21318D+01    |proj g|=  1.93637D+00
#
# At iterate   44    f=  7.20051D+01    |proj g|=  2.26014D+00
#
# At iterate   45    f=  7.18225D+01    |proj g|=  1.89147D+00
#
# At iterate   46    f=  7.17636D+01    |proj g|=  6.97182D+00
#
# At iterate   47    f=  7.15057D+01    |proj g|=  6.28035D+00
#
# At iterate   48    f=  7.13583D+01    |proj g|=  1.52391D+00
#
# At iterate   49    f=  7.13213D+01    |proj g|=  1.17885D+00
#
# At iterate   50    f=  7.12906D+01    |proj g|=  6.37428D-01
#
# At iterate   51    f=  7.12722D+01    |proj g|=  1.65809D+00
#
# At iterate   52    f=  7.12515D+01    |proj g|=  1.06709D+00
#
# At iterate   53    f=  7.12293D+01    |proj g|=  1.29824D+00
#
# At iterate   54    f=  7.10856D+01    |proj g|=  2.41904D+00
#
# At iterate   55    f=  7.08821D+01    |proj g|=  2.78025D+00
#
# At iterate   56    f=  7.07502D+01    |proj g|=  2.89623D+00
#
# At iterate   57    f=  7.05884D+01    |proj g|=  1.27468D+00
#
# At iterate   58    f=  7.05234D+01    |proj g|=  1.08223D+00
#
# At iterate   59    f=  7.05117D+01    |proj g|=  1.17135D+00
#
# At iterate   60    f=  7.05030D+01    |proj g|=  2.59818D-01
#
# At iterate   61    f=  7.05006D+01    |proj g|=  2.21044D-01
#
# At iterate   62    f=  7.04990D+01    |proj g|=  6.55160D-01
#
# At iterate   63    f=  7.04963D+01    |proj g|=  3.54271D-01
#
# At iterate   64    f=  7.04945D+01    |proj g|=  1.75421D-01
#
# At iterate   65    f=  7.04930D+01    |proj g|=  1.71078D-01
#
# At iterate   66    f=  7.04919D+01    |proj g|=  1.35809D-01
#
# At iterate   67    f=  7.04904D+01    |proj g|=  1.66074D-01
#
# At iterate   68    f=  7.04872D+01    |proj g|=  6.49631D-01
#
# At iterate   69    f=  7.04820D+01    |proj g|=  4.94024D-01
#
# At iterate   70    f=  7.04689D+01    |proj g|=  4.86061D-01
#
# At iterate   71    f=  7.04669D+01    |proj g|=  3.11824D-01
#
# At iterate   72    f=  7.04636D+01    |proj g|=  1.57499D-01
#
# At iterate   73    f=  7.04623D+01    |proj g|=  2.12111D-01
#
# At iterate   74    f=  7.04619D+01    |proj g|=  1.72148D-01
#
# At iterate   75    f=  7.04616D+01    |proj g|=  6.92297D-02
#
# At iterate   76    f=  7.04614D+01    |proj g|=  4.63317D-02
#
# At iterate   77    f=  7.04612D+01    |proj g|=  6.30771D-02
#
# At iterate   78    f=  7.04611D+01    |proj g|=  6.77600D-02
#
# At iterate   79    f=  7.04610D+01    |proj g|=  3.41741D-02
#
# At iterate   80    f=  7.04609D+01    |proj g|=  4.23542D-02
#
# At iterate   81    f=  7.04608D+01    |proj g|=  4.17226D-02
#
# At iterate   82    f=  7.04607D+01    |proj g|=  5.44698D-02
#
# At iterate   83    f=  7.04606D+01    |proj g|=  3.79309D-02
#
# At iterate   84    f=  7.04606D+01    |proj g|=  5.52906D-02
#
# At iterate   85    f=  7.04606D+01    |proj g|=  6.50149D-02
#
# At iterate   86    f=  7.04605D+01    |proj g|=  3.32169D-02
#
# At iterate   87    f=  7.04605D+01    |proj g|=  2.27306D-02
#
# At iterate   88    f=  7.04604D+01    |proj g|=  2.19108D-02
#
# At iterate   89    f=  7.04604D+01    |proj g|=  2.16187D-02
#
# At iterate   90    f=  7.04604D+01    |proj g|=  4.36918D-02
#
# At iterate   91    f=  7.04603D+01    |proj g|=  2.57890D-02
#
# At iterate   92    f=  7.04603D+01    |proj g|=  1.97509D-02
#
# At iterate   93    f=  7.04603D+01    |proj g|=  1.45014D-02
#
# At iterate   94    f=  7.04603D+01    |proj g|=  3.70076D-02
#
# At iterate   95    f=  7.04603D+01    |proj g|=  7.86458D-03
#
# At iterate   96    f=  7.04603D+01    |proj g|=  4.72827D-03
#
# At iterate   97    f=  7.04603D+01    |proj g|=  1.08666D-02
#
# At iterate   98    f=  7.04603D+01    |proj g|=  8.35301D-03
#
# At iterate   99    f=  7.04603D+01    |proj g|=  4.70322D-03
#
# At iterate  100    f=  7.04603D+01    |proj g|=  8.85877D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    21    100    114      1     0     0   8.859D-03   7.046D+01
#   F =   70.460298342728805
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
#  This problem is unconstrained.
# /Users/showndaryamadhavan/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s finished
